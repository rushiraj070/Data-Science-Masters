# %% [markdown]
# ## Assignment no 35

# %%
Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
    use each type of test.

Ans - Z-test is the statistical hypothesis used to determine whether the two samples’ means calculated are different if the 
    standard deviation is available and the sample is large. In contrast, the T-test determines how averages of different 
    data sets differ in case the standard deviation or the variance is unknown.
    
        If population data standard deviation is known and sample size is greater than or equal to 30 we use z-test and if
    population data standard deviation is not known then we use t-test.

# %%
Q2: Differentiate between one-tailed and two-tailed tests.

Ans - Definition
            A one-tailed test results from an alternative hypothesis which specifies a direction. i.e. when the alternative 
     hypothesis states that the parameter is in fact either bigger or smaller than the value specified in the null hypothesis.

        A two-tailed test results from an alternative hypothesis which does not specify a direction. i.e. when the 
    alternative hypothesis states that the null hypothesis is wrong.

        One-tailed Tests
               1. A one-tailed test may be either left-tailed or right-tailed.
               2. A left-tailed test is used when the alternative hypothesis states that the true value of the parameter 
                  specified in the null hypothesis is less than the null hypothesis claims.
               3. A right-tailed test is used when the alternative hypothesis states that the true value of the parameter 
                  specified in the null hypothesis is greater than the null hypothesis claims.

        Two-tailed Tests
            The main difference between one-tailed and two-tailed tests is that one-tailed tests will only have one critical
        region whereas two-tailed tests will have two critical regions. If we require a 100(1−α) % confidence interval we 
        have to make some adjustments when using a two-tailed test.

        The confidence interval must remain a constant size, so if we are performing a two-tailed test, as there are twice 
        as many critical regions then these critical regions must be half the size. This means that when we read the tables,
        when performing a two-tailed test, we need to consider α/2 rather than α.

    Example
    A light bulb manufacturer claims that its' energy saving light bulbs last an average of 60 days. Set up a hypothesis 
    test to check this claim and comment on what sort of test we need to use.

    Solution
        So we have Ho : The mean lifetime of an energy-saving light bulb is 60 days.
                   Ha : The mean lifetime of an energy-saving light bulb is not 60 days.
    
    Because of the “is not” in the alternative hypothesis, we have to consider both the possibility that the lifetime of the 
    energy-saving light bulb is greater than 60 and that it is less than 60. This means we have to use a two-tailed test.

# %%
Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
each type of error.

Ans - A Type 1 error (false-positive) occurs if an investigator rejects a null hypothesis that is actually true in the 
    population; a Type 2 error (false-negative) occurs if the investigator fails to reject a null hypothesis that is 
    actually false in the population.
    
    There are four outcomes on Error based Scenarios:
        1. We reject the null hypothesis (Ho) when it is False in reality => GOOD SCENARIO
        
        2. We reject the null hypothesis (Ho) when it is True in reality => Type 1 error
        
        3. We retain the null hypothesis (Ho) when it is False in reality => Type 2 error
        
        4. We retain the null hypothesis (Ho) when it is True in reality => GOOD SCENARIO

# %%
Q4: Explain Bayes's theorem with an example.

Ans - Bayes’ theorem describes the probability of occurrence of an event related to any condition. It is also considered for
    the case of conditional probability. Bayes theorem is also known as the formula for the probability of “causes”. 
    
    Formula:
                  P(A) * P(B|A)
        P(A|B) = --------------
                     P(B)
    
    For example: 
        
        A bag contains 4 white and 6 black balls. One ball is drawn at random from one of the bags, Find the probability 
        that it was found to be black.
    
    Solution:
        
        Also, P(W)  = 4/10 = 2/5
              P(B) =  = 6/10 = 3/5
            
              P(W|B) = 4/9 
              P(B|W) = 6/9 = 2/3
            
            By using Bayes’ theorem, the probability of drawing a black ball is,
                   
                 P(W) * P(B|W)      (2/5) * (2/3)
        P(W|B) = -------------- = --------------- = 4/9
                     P(B)               (3/5)
               
        
                 P(B) * P(W|B)      (3/5) * (4/9)
        P(B|W) = -------------- = --------------- = 2/3
                       P(W)             (2/5)

# %%
Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.

Ans - A confidence interval is the mean of your estimate plus and minus the variation in that estimate. This is the range 
    of values you expect your estimate to fall between if you redo your test, within a certain level of confidence. 
    Confidence, in statistics, is another way to describe probability.
    
    Your desired confidence level is usually one minus the alpha (α) value you used in your statistical test:
         Confidence level = 1 − α

    So if you use an alpha value of p < 0.05 for statistical significance, then your confidence level would be 
    1 − 0.05 = 0.95, or 95%.
    
    Problem - We measure the heights of 40 randomly chosen men, and get a mean height of 175cm, We also know the standard 
        deviation of men's heights is 20cm.
        
       Ans - 
    
        The 95% Confidence Interval (we show how to calculate it later) is: confidence interval 175 plus minus 6.2
        The "±" means "plus or minus", so 175cm ± 6.2cm means
        175cm − 6.2cm = 168.8cm to 175cm + 6.2cm = 181.2cm
        And our result says the true mean of ALL men (if we could measure all their heights) is likely to be between 168.8cm 
        and 181.2cm But it might not be!
        
        The "95%" says that 95% of experiments like we just did will include the true mean, but 5% won't.
        So there is a 1-in-20 chance (5%) that our Confidence Interval does NOT include the true mean.

# %%
Q6. Use Bayes Theorem to calculate the probability of an event occurring given prior knowledge of the
    events probability and new evidence. Provide a sample problem and solution.

Ans - Bayes' Theorem follows simply from the axioms of conditional probability. Conditional probability is the probability
      of an event given that another event occurred. Bayes' Theorem thus gives the probability of an event based on new 
      information that is, or may be, related to that event. The formula can also be used to determine how the probability 
      of an event occurring may be affected by hypothetical new information, supposing the new information will turn out to 
      be true. 

     Imagine there is a drug test that is 98% accurate, meaning that 98% of the time, it shows a true positive result for 
    someone using the drug, and 98% of the time, it shows a true negative result for nonusers of the drug.
    
    Next, assume 0.5% of people use the drug. If a person selected at random tests positive for the drug, the following 
    calculation can be made to determine the probability the person is actually a user of the drug.
         (0.98 x 0.005) / [(0.98 x 0.005) + ((1 - 0.98) x (1 - 0.005))] 
        = 0.0049 / (0.0049 + 0.0199) 
        = 19.76%
        
    Bayes' Theorem shows that even if a person tested positive in this scenario, there is a roughly 80% chance the person 
    does not take the drug.

# %%
Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
    of 5. Interpret the results.

Ans - Assumed n = 100

        Lower C.I = 50 - (1.96)(5) = 40.2
        Higher C.I = 50 + (1.96)(5) = 59.8
        
        40.2 <= μ <= 59.8

        Conclusion - So we can say with 95% confidence that the confidence interval for a sample of data is in between 
                    40.2 to 59.8.

# %%
Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
    Provide an example of a scenario where a larger sample size would result in a smaller margin of error.
    
Ans - A margin of error tells you how many percentage points your results will differ from the real population value. For 
    example, a 95% confidence interval with a 4 percent margin of error means that your statistic will be within 4 
    percentage points of the real population value 95% of the time.
        However, there’s a little more to the formal definition. The margin of error is defined a the range of values below 
    and above the sample statistic in a confidence interval. The confidence interval is a way to show what the uncertainty 
    is with a certain statistic (i.e. from a poll or survey).
        It is intuitive that a greater sample size will be a closer representative of the population than a smaller sample 
    size. Hence, the larger the sample size, the smaller the sample standard error and therefore the smaller the margin of 
    error.

# %%
Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
    standard deviation of 5. Interpret the results.

Ans - 
                 x - µ 
            z = -------
                   σ
            
            z = (75 - 70)/5
            
            z = 1

# %%
Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
    of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
    significantly effective at a 95% confidence level using a t-test.
    
Ans- Given x̄ = 6 ,  μ = 0 , s = 2.5 , n = 50

    1. Defining Hypothesis
    
            H0: μ = 0 (The drug is not effective)
            Ha: μ < 0 (The drug is effective)

    2. Determine the level of significance (α).
            C.I. = 95%, which means that α = 1 - 0.95 = 0.05.

    3. Calculate the test statistic. The test statistic for a t-test is:

        t = (x̄ - μ) / (s / sqrt(n))
        t = (6 - 0) / (2.5 / sqrt(50)) = 16.97

    4. Critical value -
        The critical value for a one-tailed t-test with 49 degrees of freedom at a 95% confidence level is -1.676.
        
        The t-statistic (16.97) is greater than the critical value (1.676), so we reject the null hypothesis. 
        
    5. Conclusion -
        We can conclude that the drug is significantly effective at a 95% confidence level.

# %%
Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
    confidence interval for the true proportion of people who are satisfied with their job.

# %%
To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job, we can use the 
following formula:

CI = p ± z*sqrt((p*(1-p))/n)

where:
p = the sample proportion (65% or 0.65 in this case)
z = the z-score for the desired confidence level (1.96 for 95% confidence)
n = the sample size (500 in this case)

Plugging in the values, we get:

CI = 0.65 ± 1.96*sqrt((0.65*(1-0.65))/500)
CI = 0.65 ± 0.048
CI = (0.602, 0.698)

Therefore, we can be 95% confident that the true proportion of people who are satisfied with their job lies between 0.602 and 0.698. Note that we did not need to know the standard deviation of the population because we used the sample proportion to estimate it.

# %%
Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
    Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
    with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
    significant difference in student performance using a t-test with a significance level of 0.01.
    
Ans - α = 0.01, dof  = 2-1 = 1

    For Sample A:
       x1 = 85, σ1 = 6, 
       t_score99 = 6.3138 (By t Table) (two tail test)
       std_error =  σ1 / √n1 = 6/√1 = 6
       neg_CI = x1 - (t_score99 * std_error) = 85 - (6.3138 * 6) = 47.41
       pos_CI = x1 + (t_score99 * std_error) = 85 + (6.3138 * 6) = 122.88
    
    For Sample B:
       x2 = 82, σ2 = 8
       t_score99 = 6.3138 (By t Table) (two tail test)
       std_error =  σ2 / √n2 = 8/√1 = 8
       neg_CI = x2 - (t_score99 * std_error) = 82 - (6.3138 * 8) = 31.49
       pos_CI = x2 + (t_score99 * std_error) = 82 + (6.3138 * 8) = 132.51
    
    99% of scores for sample A are between 47.41 to 122.88 while for sample B are between 31.49 to 132.51.
    
    Hence we Reject the Null Hypothesis that the population means for the two teaching methods have a
    significant difference in student performance.

# %%
Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
of 65. Calculate the 90% confidence interval for the true population mean.

Ans - M = 60, S = 8, n = 50, x = 65, C.I. = 90%, 

    dof = 50-1 = 49, 

    Defining Hypothesis
    
            H0: M = 60
            Ha: M !=60
            
    Determining the level of significance (a) = 0.05
    
    from t Table, t_score90 = 1.6766 (Two table test)
    
    t-new = 65 - 60 / (8/√50) = 4.42
    
    Since t-new = 4.42 is greater than 1.6766 we reject the Null Hypothesis.

# %%
Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

Ans- Given x̄ = 0.25 ,  μ =  , s = 0.05 , n = 30

    1. Defining Hypothesis
    
            Ho: μ = 0 (caffeine has a significant effect on reaction time)
            Ha: μ != 0 (caffeine has a no significant effect on reaction time)

    2. Determine the level of significance (α).
            C.I. = 90%, which means that α = 1 - 0.90 = 0.1.
        
    3. dof = n - 1 = 30 - 1 = 29

    3. Calculate the test statistic. The test statistic for a t-test is:

        t = (x̄ - μ) / (s / sqrt(n))
        t = (0.25 - 0) / (0.05 / sqrt(30)) = 27.38

    4. Critical value -
        The critical value for a two-tailed t-test with 29 degrees of freedom at a 90% confidence level is 1.6991.
        
        The t-statistic (27.28) is greater than the critical value (1.6991), so we reject the null hypothesis. 
        
    5. Conclusion -
        We can conclude that the the caffeine has a significant effect on reaction time at a 90% confidence level

# %% [raw]
# Please refer to the below approach:
#
# If you have the sample mean, sample standard deviation, and sample size, you can use a t-test to determine if the sample mean is significantly different from a hypothesized population mean. In this case, the sample mean is 6 pounds, and the sample standard deviation is 2.5 pounds, with a sample size of 50.
#
# To conduct a hypothesis test at a 95% confidence level using a t-test, we can follow these steps:
#
# State the null hypothesis (H0) and the alternative hypothesis (Ha). In this case, we want to test if the drug is significantly effective, so our hypotheses are:
#
# H0: μ = 0 (The drug is not effective)
# Ha: μ < 0 (The drug is effective)
#
# Determine the level of significance (α). We are given that the confidence level is 95%, which means that α = 0.05.
#
# Calculate the test statistic. The test statistic for a t-test is:
#
# t = (x̄ - μ) / (s / sqrt(n))
#
# Where x̄ is the sample mean, μ is the hypothesized population mean, s is the sample standard deviation, and n is the sample size.
#
# In this case, we can use the sample mean and sample standard deviation as estimates of the population mean and population standard deviation, respectively, so:
#
# t = (6 - 0) / (2.5 / sqrt(50)) = 13.42
#
# Determine the critical value. The critical value for a one-tailed t-test with 49 degrees of freedom at a 95% confidence level is -1.676.
#
# Compare the test statistic with the critical value. If the test statistic is less than the critical value, we reject the null hypothesis. Otherwise, we fail to reject the null hypothesis.
#
# In this case, the test statistic (13.42) is greater than the critical value (-1.676), so we reject the null hypothesis. We can conclude that the drug is significantly effective at a 95% confidence level.
#
# Note that the confidence interval is not used in this hypothesis test, as we are only interested in testing whether the drug is significantly effective or not. If you wanted to calculate the confidence interval for the population mean weight loss, you would need to know the population mean or use a confidence interval formula based on the sample mean and standard deviation.

# %% [raw]
# No, the value of "p" should not be the number of people who reported being satisfied (i.e., 325 in this case). Instead, "p" represents the proportion of the entire population who are satisfied with their current job.
#
# The sample proportion, denoted by "p-hat", is the proportion of the sample who reported being satisfied. In this case, the sample proportion is 0.65, or 65% (since 65% of the 500 people surveyed reported being satisfied with their current job).
#
# We use the sample proportion to estimate the population proportion, and then use the formula I provided in my previous answer to calculate the 95% confidence interval for the true population proportion.
#
# 6:58 pm
