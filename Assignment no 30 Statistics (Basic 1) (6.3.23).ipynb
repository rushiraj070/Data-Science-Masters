# %% [markdown]
# # Assignment No. 30

# %% [markdown]
# ### Statistics (Basic 1)

# %%
Q1. What is Statistics?

Ans -  Statistics is the study of the collection, analysis, interpretation, presentation, and organization of data.
      Statistics make us learn to utilize a restricted sample datset to make accurate determinations about a more prominent 
      populated dataset. The utilization of tables, diagrams, and graphs assumes a crucial part in introducing the information 
    being utilized to reach these determinations.

# %%
Q2. Define the different types of statistics and give an example of when each type might be used.

Ans - Statistics have majorly categorised into two types:
    
1. Descriptive Statistics
            In this type of statistics, the data is summarised through the given observations. The summarisation is one from a 
        sample of population using parameters such as the mean or standard deviation.

            Descriptive statistics is a way to organise, represent and describe a collection of data using tables, graphs, 
        and summary measures. 
    
    For example, the collection of people in a city using the internet or using Television.

        Descriptive statistics are also categorised into four different categories:
                a. Measure of frequency
                b. Measure of dispersion
                c. Measure of central tendency
                d. Measure of position

            The frequency measurement displays the number of times a particular data occurs. Range, Variance, Standard Deviation 
        are measures of dispersion. It identifies the spread of data. Central tendencies are the mean, median and mode of the 
        data. And the measure of position describes the percentile and quartile ranks.

2. Inferential Statistics
    This type of statistics is used to interpret the meaning of Descriptive statistics. That means once the data has been 
collected, analysed and summarised then we use these stats to describe the meaning of the collected data. Or we can 
say, it is used to draw conclusions from the data that depends on random variations such as observational errors, sampling variation, etc.

    Inferential Statistics is a method that allows us to use information collected from a sample to make decisions, 
predictions or inferences from a population. It grants us permission to give statements that goes beyond the available
data or information. 

    For example, deriving estimates from hypothetical research.

# %%
Q3. What are the different types of data and how do they differ from each other? Provide an example of
each type of data.

Ans - 
        The data is classified into majorly two categories:
            1. Quantitative Data
            2. Qualitative Data

Let us discuss the different types of data in Statistics herewith examples.

1. Quantitative or Numerical Data
        Quantitative data is also known as numerical data which represents the numerical value (i.e., how much, how often,
    how many). Numerical data gives information about the quantities of a specific thing. Some examples of numerical data are 
    height, length, size, weight, and so on. The quantitative data can be classified into two different types based on the data
    sets. The two different classifications of numerical data are 
        
        a. Discrete data
        b. Continuous data.

    a. Discrete Data
        Discrete data can take only discrete values. Discrete information contains only a finite number of possible values. 
    Those values cannot be subdivided meaningfully. Here, things can be counted in whole numbers.

    Example: Number of students in the class

    b. Continuous Data
        Continuous data is data that can be calculated. It has an infinite number of probable values that can be selected 
    within a given specific range.

    Example: Temperature range

2. Qualitative or Categorical Data
        Qualitative data, also known as the categorical data, describes the data that fits into the categories. Qualitative data 
    are not numerical. The categorical information involves categorical variables that describe the features such as a person’s 
    gender, home town etc. Categorical measures are defined in terms of natural language specifications, but not in terms of 
    numbers.

    Sometimes categorical data can hold numerical values (quantitative value), but those values do not have a mathematical 
    sense. Examples of the categorical data are birthdate, favourite sport, school postcode. Here, the birthdate and school
    postcode hold the quantitative value, but it does not give numerical meaning.

    a. Nominal Data
        Nominal data is one of the types of qualitative information which helps to label the variables without providing the 
    numerical value. Nominal data is also called the nominal scale. It cannot be ordered and measured. But sometimes, the
    data can be qualitative and quantitative. Examples of nominal data are letters, symbols, words, gender etc.

    The nominal data are examined using the grouping method. In this method, the data are grouped into categories, and then
    the frequency or the percentage of the data can be calculated. These data are visually represented using the pie charts.

    Example: Number of Blood Groups of Human-Beings.
    
    b. Ordinal Data
        Ordinal data/variable is a type of data that follows a natural order. The significant feature of the nominal data 
    is that the difference between the data values is not determined. This variable is mostly found in surveys, finance, 
    economics, questionnaires, and so on.

    The ordinal data is commonly represented using a bar chart. These data are investigated and interpreted through many 
    visualisation tools. The information may be expressed using tables in which each row in the table shows the distinct 
    category.

    Example: Ranks of students w.r.t. percentile in the class

# %%
Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
    
(i) Grading in exam: A+, A, B+, B, C+, C, D, E
Ans- Qualitative (Ordinal)

(ii) Colour of mangoes: yellow, green, orange, red
Ans- Qualitative (Nominal)

(iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...]
Ans- Quantitative (Continuous)

(iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ...]
Ans- Quantitative (Discrete)

# %%
Q5. Explain the concept of levels of measurement and give an example of a variable for each level.

Ans - 
        The level of measurement refers to the relationship among the values that are assigned to the attributes for a 
    variable.
    There are 4 levels of measurement, which can be ranked from low to high: 
    
    1. Nominal: The data can only be categorized and order doesn't matters.
       e.g. Colors, Labels, Gender etc.
    
    2. Ordinal: The data can be categorized and ranked but difference cannot be measured.
                
       e.g. Qualification levels w.r.t. education, Hierarchical position in organizations.
    
    3. Interval: The data can be categorized and ranked, and evenly spaced.
                Difference can be easily measured (excluding ratio).
                Doesn't have a '0' starting value.
       e.g. Temperature, Sensex, Nifty etc.
    
    4. Ratio: The data can be categorized, ranked, evenly spaced and has a natural zero.
       e.g. Grades, Discount offer etc.

# %%
Q6. Why is it important to understand the level of measurement when analyzing data? Provide an example to illustrate your 
    answer.
    
Ans - It is important to understand the level of measurement of variables in research, because the level of measurement 
    determines the type of statistical analysis that can be conducted, and, therefore, the type of conclusions that can be 
    drawn from the research.
    
    e.g. Here I want to give the recent example of COVID vaccination scenario.
        The levels with respect to frequency of patients occuring in vicinity have helped the health ministry or departement to 
        categorise the zones with repect toi number of patients, also the number of facilities/services to keep openly available
        for emergency like beds in hospitals, ambulances, PPE kits for medical team, Oxygen supply and the numnber of vaccines etc.

# %%
Q7. How nominal data type is different from ordinal data type.

Ans -   Nominal data is one of the types of qualitative information which order and ranking does not matter.
        Examples of nominal data are letters, symbols, words, gender etc.
    
        On the other hand Ordinal data the order and ranking do matters.

# %%
Q8. Which type of plot can be used to display data in terms of range?

Ans - Histogram is the type of plot which can be used to display data in terms of range.

# %%
Q9. Describe the difference between descriptive and inferential statistics. Give an example of each type of statistics and 
explain how they are used.

Ans - Descriptive Statistics is the type of statistics, the data is summarised through the given observations. The 
    summarisation is one from a sample of population using parameters such as the mean or standard deviation.
        The frequency measurement displays the number of times a particular data occurs. Range, Variance, Standard Deviation 
    are measures of dispersion. It identifies the spread of data. Central tendencies are the mean, median and mode of the 
    data. And the measure of position describes the percentile and quartile ranks.

     While Inferential Statistics is the type of statistics which is used to interpret the meaning of Descriptive statistics.
    That means once the data has been collected, analysed and summarised then we use these stats to describe the meaning of the collected data. Or we can 
    say, it is used to draw conclusions from the data that depends on random variations such as observational errors, sampling variation, etc.

     Inferential Statistics is a method that allows us to use information collected from a sample to make decisions, 
    predictions or inferences from a population. It grants us permission to give statements that goes beyond the available
    data or information. 

    For example, deriving estimates from hypothetical research.
        Consider if we have the data for salary of employees in a particular organization which belongs to a particular sector.
    Now based on that data we can find minimum, average and maximum salary for employee base on various parameters like education,
    experience level etc. and this can be considered as Descriptive statistics.
     And that descriptive statistics considering the dataset as a sample dataset if we apply to various organizations in 
    that respective sector then it will be considered as inferential statistics for populated dataset.

# %%
Q10. What are some common measures of central tendency and variability used in statistics? Explain
how each measure can be used to describe a dataset.

Ans - Measures of central tendency tell us what is common or typical about our variable. Three measures of central 
    tendency are the mode, the median and the mean. The mode is used almost exclusively with nominal-level data, 
    as it is the only measure of central tendency available for such variables.
    
    Measures of central tendency:
        1. Mean: average of data values

        2. Median: “middle value” or the average of “middle two values” in a data set when the numbers are arranged in an 
        order.

        3. Mode: value that occurs with greatest frequency.

    Measures of variation
        1. Standard deviation: measure of how much data values are deviated away from mean.
        
        2. Variance: square of the standard deviation.
        
        3. Range: difference between the maximum value and the minimum value in a data set,
                Range = maximum value – minimum value
